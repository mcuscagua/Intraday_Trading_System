# %%
import trading_system as api
API = api.API()

# %%
len(API.Tickers)
# Out:
# 126

# %%
API.stream_price(API.Tickers, multiple=True)

# %%
API.stream_price('EUR_USD')
# Out:
# OK
# EUR_USD
# [{'price': '1.07307', 'liquidity': 10000000}] / [{'price': '1.07326', 'liquidity': 10000000}]
#
#
# {"type":"HEARTBEAT","time":"2020-03-23T04:27:40.342988691Z"}
# EUR_USD
# [{'price': '1.07306', 'liquidity': 10000000}] / [{'price': '1.07324', 'liquidity': 10000000}]
#
#
# {"type":"HEARTBEAT","time":"2020-03-23T04:27:45.350115831Z"}
# EUR_USD
# [{'price': '1.07309', 'liquidity': 10000000}] / [{'price': '1.07328', 'liquidity': 10000000}]
#
#
# {"type":"HEARTBEAT","time":"2020-03-23T04:27:50.351832591Z"}
# {"type":"HEARTBEAT","time":"2020-03-23T04:27:55.360625513Z"}
# EUR_USD
# [{'price': '1.07305', 'liquidity': 10000000}] / [{'price': '1.07328', 'liquidity': 10000000}]
#
#
# {"type":"HEARTBEAT","time":"2020-03-23T04:28:00.365548745Z"}
# EUR_USD
# [{'price': '1.07305', 'liquidity': 10000000}] / [{'price': '1.07325', 'liquidity': 10000000}]
#
#
# EUR_USD
# [{'price': '1.07307', 'liquidity': 10000000}] / [{'price': '1.07326', 'liquidity': 10000000}]
#
#
# ...
