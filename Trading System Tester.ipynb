# %%
import trading_system as api

API = api.API()

# %%
Tickers = list(API.Tickers.keys())
API.stream_price(Tickers, multiple=True)
# Out:
# OK
# b'{"type":"PRICE","time":"2020-03-06T22:02:01.143671348Z","bids":[{"price":"1.12844","liquidity":10000000}],"asks":[{"price":"1.12944","liquidity":10000000}],"closeoutBid":"1.12844","closeoutAsk":"1.12944","status":"non-tradeable","tradeable":false,"instrument":"EUR_USD"}'
# b'{"type":"PRICE","time":"2020-03-06T22:00:00.119906580Z","bids":[{"price":"0.86461","liquidity":10000000}],"asks":[{"price":"0.86611","liquidity":10000000}],"closeoutBid":"0.86461","closeoutAsk":"0.86611","status":"non-tradeable","tradeable":false,"instrument":"EUR_GBP"}'
# b'{"type":"PRICE","time":"2020-03-06T22:00:00.047480782Z","bids":[{"price":"1.69945","liquidity":10000000}],"asks":[{"price":"1.70145","liquidity":10000000}],"closeoutBid":"1.69945","closeoutAsk":"1.70145","status":"non-tradeable","tradeable":false,"instrument":"EUR_AUD"}'
# ...
