# %%
import trading_system as api
API = api.API()

# %%
len(API.Tickers)

# %%
API.stream_price(API.Tickers, multiple=True)

# %%
API.stream_price('USD_TRY')
# Out:
# OK
# {'type': 'PRICE', 'time': '2020-04-10T04:16:37.416827336Z', 'bids': [{'price': '6.66916', 'liquidity': 2000000}], 'asks': [{'price': '6.70286', 'liquidity': 2000000}], 'closeoutBid': '6.66916', 'closeoutAsk': '6.70286', 'status': 'tradeable', 'tradeable': True, 'instrument': 'USD_TRY'}
#
#
# {"type":"HEARTBEAT","time":"2020-04-10T04:16:42.459305613Z"}
# {'type': 'PRICE', 'time': '2020-04-10T04:16:44.642103859Z', 'bids': [{'price': '6.66934', 'liquidity': 2000000}], 'asks': [{'price': '6.70291', 'liquidity': 2000000}], 'closeoutBid': '6.66934', 'closeoutAsk': '6.70291', 'status': 'tradeable', 'tradeable': True, 'instrument': 'USD_TRY'}
#
#
# {'type': 'PRICE', 'time': '2020-04-10T04:16:44.848046464Z', 'bids': [{'price': '6.66874', 'liquidity': 2000000}], 'asks': [{'price': '6.70281', 'liquidity': 2000000}], 'closeoutBid': '6.66874', 'closeoutAsk': '6.70281', 'status': 'tradeable', 'tradeable': True, 'instrument': 'USD_TRY'}
#
#
# ...
