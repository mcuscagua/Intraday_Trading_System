# %%
import trading_system as api
API = api.API()

# %%
API.stream_price(API.Tickers, multiple=True)
# Out:
# OK
# EUR_USD
# [{'price': '1.12844', 'liquidity': 10000000}] / [{'price': '1.12944', 'liquidity': 10000000}]
#
#
# EUR_GBP
# [{'price': '0.86461', 'liquidity': 10000000}] / [{'price': '0.86611', 'liquidity': 10000000}]
#
#
# EUR_AUD
# [{'price': '1.69945', 'liquidity': 10000000}] / [{'price': '1.70145', 'liquidity': 10000000}]
#
#
# EUR_CAD
# [{'price': '1.51356', 'liquidity': 10000000}] / [{'price': '1.51506', 'liquidity': 10000000}]
#
#
# EUR_SGD
# [{'price': '1.55446', 'liquidity': 5000000}] / [{'price': '1.55810', 'liquidity': 5000000}]
#
#
# EUR_CHF
# [{'price': '1.05777', 'liquidity': 10000000}] / [{'price': '1.05927', 'liquidity': 10000000}]
#
#
# EUR_JPY
# [{'price': '118.781', 'liquidity': 10000000}] / [{'price': '118.931', 'liquidity': 10000000}]
#
#
# EUR_NZD
# [{'price': '1.77465', 'liquidity': 10000000}] / [{'price': '1.77665', 'liquidity': 10000000}]
#
#
# EUR_HKD
# [{'price': '8.76872', 'liquidity': 5000000}] / [{'price': '8.77875', 'liquidity': 5000000}]
#
#
# ...
